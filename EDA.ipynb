# %% [markdown]
# # Imports

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('ggplot') #https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
unis_1819 = pd.read_pickle("data/unis_1819.pkl")
unis_2122 = pd.read_pickle("data/unis_2122.pkl")
summary_1819 = pd.read_pickle("data/summary_1819.pkl")
summary_2122 = pd.read_pickle("data/summary_2122.pkl")
course_1819 = pd.read_pickle("data/course_1819.pkl")
course_2122 = pd.read_pickle("data/course_2122.pkl")

# %% [markdown]
# # EDA

# %% [markdown]
# ### By country

# %%
summary_1819.head()
# Out:
#                          Q1         Q2         Q3         Q4         Q5  \
# England           88.778160  81.924411  84.800519  81.225215  84.075056
# Scotland          89.457671  83.012992  85.541630  80.554780  83.527915
# Wales             89.935977  83.503667  84.982081  82.014255  84.407333
# Northern Ireland  89.024086  82.205276  85.253734  83.277861  83.700776
# UK                88.892944  82.091855  84.876337  81.263357  84.041340
#
#                          Q6         Q7         Q8         Q9        Q10  ...  \
# England           84.886815  80.889026  72.525879  72.712395  74.600840  ...
# Scotland          84.040667  78.568853  71.681497  73.167350  65.166609  ...
# Wales             85.421609  82.467954  75.067815  75.181148  75.042689  ...
# Northern Ireland  85.201340  84.200163  73.878637  74.954569  68.803944  ...
# UK                84.857219  80.872410  72.621323  72.923558  73.772077  ...
#
# ...

# %%
summary_2122.head()
# Out:
#                          Q1         Q2         Q3         Q4         Q5  \
# England           79.737075  84.147697  77.662464  81.305213  75.903553
# Scotland          82.109712  86.462607  80.596142  83.842190  77.596963
# Wales             80.525789  85.011885  79.146727  81.539570  76.456929
# Northern Ireland  81.095008  85.277551  77.698817  82.520124  78.952124
# UK                79.992741  84.397011  77.964070  81.544757  76.133924
#
#                          Q6         Q7         Q8         Q9        Q10  ...  \
# England           79.071665  79.465628  81.224499  76.590480  68.786830  ...
# Scotland          79.973417  81.229188  82.608500  76.144778  65.740663  ...
# Wales             79.132272  79.015333  81.310633  77.152465  69.522817  ...
# Northern Ireland  81.038071  80.047217  82.278878  80.933878  67.921884  ...
# UK                79.191428  79.597518  81.362342  76.682378  68.560322  ...
#
# ...

# %%
summary_1819.describe()
# Out:
#               Q1         Q2         Q3         Q4         Q5         Q6  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   89.217767  82.547640  85.090860  81.667094  83.950484  84.881530
# std     0.476879   0.678953   0.304907   1.038099   0.344021   0.524793
# min    88.778160  81.924411  84.800519  80.554780  83.527915  84.040667
# 25%    88.892944  82.091855  84.876337  81.225215  83.700776  84.857219
# 50%    89.024086  82.205276  84.982081  81.263357  84.041340  84.886815
# 75%    89.457671  83.012992  85.253734  82.014255  84.075056  85.201340
# max    89.935977  83.503667  85.541630  83.277861  84.407333  85.421609
#
#               Q7         Q8         Q9        Q10  ...        Q19        Q20  \
# count   5.000000   5.000000   5.000000   5.000000  ...   5.000000   5.000000
# mean   81.399681  73.155030  73.787804  71.477232  ...  87.147043  87.401626
# std     2.093817   1.326115   1.182279   4.321636  ...   0.629920   0.578953
# ...

# %%
summary_1819.iloc[4,:-1].hist(bins = 5)
plt.xlabel("% agreeement")
plt.xlim([50,90])
plt.ylabel("Number of questions")
plt.show()

# %%
summary_2122.describe()
# Out:
#               Q1         Q2         Q3         Q4         Q5         Q6  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   80.692065  85.059350  78.613644  82.150371  77.008699  79.681371
# std     0.948788   0.906752   1.262743   1.055119   1.266292   0.842499
# min    79.737075  84.147697  77.662464  81.305213  75.903553  79.071665
# 25%    79.992741  84.397011  77.698817  81.539570  76.133924  79.132272
# 50%    80.525789  85.011885  77.964070  81.544757  76.456929  79.191428
# 75%    81.095008  85.277551  79.146727  82.520124  77.596963  79.973417
# max    82.109712  86.462607  80.596142  83.842190  78.952124  81.038071
#
#               Q7         Q8         Q9        Q10  ...        Q19        Q20  \
# count   5.000000   5.000000   5.000000   5.000000  ...   5.000000   5.000000
# mean   79.870977  81.756970  77.500796  68.106503  ...  70.961396  64.809895
# std     0.843655   0.639524   1.952220   1.441009  ...   2.499667   2.602257
# ...

# %%
summary_2122.iloc[4,:-1].hist(bins = 5)
plt.xlabel("% agreeement")
plt.xlim([50,90])
plt.ylabel("Number of questions")
plt.show()

# %%
#plt.figure(figsize = (4, 4))
plt.pie(summary_1819["avg_res"][:-1], labels = ["England","Scotland","Wales","Northern Ireland"], autopct='%1.1f%%')
plt.title("Responses by country in 2018-2019 surverys.")
plt.show()

# %%
#plt.figure(figsize = (4, 4))
plt.pie(summary_2122["avg_res"][:-1], labels = ["England","Scotland","Wales","Northern Ireland"], autopct='%1.1f%%')
plt.title("Responses by country in 2021-2022 surverys.")
plt.show()

# %%
diffc = summary_2122 - summary_1819
diffc #analyse individual question later in corr analysis
# Out:
#                         Q1        Q2        Q3        Q4        Q5        Q6  \
# England          -9.041085  2.223287 -7.138055  0.079998 -8.171502 -5.815151
# Scotland         -7.347959  3.449614 -4.945488  3.287410 -5.930952 -4.067250
# Wales            -9.410188  1.508219 -5.835354 -0.474685 -7.950405 -6.289337
# Northern Ireland -7.929078  3.072275 -7.554917 -0.757738 -4.748652 -4.163269
# UK               -8.900203  2.305157 -6.912267  0.281400 -7.907416 -5.665790
#
#                         Q7         Q8        Q9       Q10  ...        Q19  \
# England          -1.423398   8.698620  3.878086 -5.814009  ... -17.047026
# Scotland          2.660335  10.927003  2.977428  0.574054  ... -16.421329
# Wales            -3.452621   6.242819  1.971317 -5.519872  ... -17.664000
# Northern Ireland -4.152946   8.400240  5.979309 -0.882060  ... -12.867819
# UK               -1.274892   8.741019  3.758820 -5.211755  ... -16.928062
#
# ...

# %%
diffc.iloc[:,-2] #change in student satisfaction - 2018-2019 -> 2021-2022
# Out:
# England            -15.952463
# Scotland           -15.660949
# Wales              -16.847933
# Northern Ireland   -14.012691
# UK                 -15.931557
# Name: Q27, dtype: float64

# %%
print(f"Largest positive change is {max(diffc.iloc[-1,:-1])} for question {diffc.iloc[-1,:-1].idxmax(axis=0)}")
print(f"Largest negative change is {min(diffc.iloc[-1,:-1])} for question {diffc.iloc[-1,:-1].idxmin(axis=0)}")
# Out:
# Largest positive change is 22.314105709795378 for question Q26
# Largest negative change is -22.702871854594164 for question Q20

# %%
diffc.iloc[-1,:-1] #difference in response, - avg_res
# Out:
# Q1     -8.900203
# Q2      2.305157
# Q3     -6.912267
# Q4      0.281400
# Q5     -7.907416
# Q6     -5.665790
# Q7     -1.274892
# Q8      8.741019
# Q9      3.758820
# Q10    -5.211755
# Q11    -4.276325
# Q12   -16.919507
# Q13   -12.053032
# Q14    -5.442017
# Q15     3.995133
# Q16     2.483454
# Q17    -4.721022
# Q18   -14.661926
# Q19   -16.928062
# Q20   -22.702872
# Q21     6.145229
# Q22   -13.519349
# Q23    -6.972840
# Q24    -0.968905
# Q25    18.760876
# Q26    22.314106
# Q27   -15.931557
# Name: UK, dtype: float64

# %%
#do this to get red and green
x = np.arange(27)
y = diffc.iloc[-1,:-1]
mask1 = y < 0
mask2 = y >= 0

plt.bar(x[mask1], y[mask1], color = 'red')
plt.bar(x[mask2], y[mask2], color = 'green')
plt.xlabel("Questions")
plt.xticks(x, summary_1819.columns[:-1], rotation = 45)
plt.ylabel("Change in agreement % from benchmark")
plt.ylim([-23,23])
plt.show()

# %%
negatives = len(diffc.iloc[-1,:-1][diffc.iloc[-1,:-1] < 0]) #find all questions that recorded reduced agreeement / all questions
print(f"Out of 27 questions, {negatives} questions recorded reductions in agreement, or {negatives/27:.2f}%.")
print(f"Mean difference: {np.mean(diffc.iloc[-1,:-1])}")
# Out:
# Out of 27 questions, 18 questions recorded reductions in agreement, or 0.67%.
# Mean difference: -3.7846127431920475

# %% [markdown]
# ### By uni

# %%
unis_2122
# Out:
#                              University     Q01     Q02     Q03     Q04  \
# 0                University of Aberdeen  89.710  83.805  87.465  80.030
# 1                    Abertay University  89.885  82.375  82.535  77.345
# 2                Aberystwyth University  91.130  85.960  87.490  79.215
# 3           Abingdon and Witney College  84.135  83.975  75.960  72.115
# 4                 ACM Guildford Limited  72.950  66.890  56.565  56.515
# ..                                  ...     ...     ...     ...     ...
# 348                  University of York  87.670  82.130  86.295  74.125
# 349                        York College  84.225  88.335  83.150  86.485
# 350             York St John University  86.610  81.475  82.565  78.455
# 351        Hull and York Medical School  77.170  82.070  92.415  77.335
# 352  Brighton and Sussex Medical School  92.250  90.865  95.675  84.615
#
#         Q05     Q06     Q07     Q08     Q09  ...     Q18     Q19     Q20  \
# ...

# %%
unis_1819.describe()
# Out:
#               Q01         Q02         Q03         Q04         Q05         Q06  \
# count  353.000000  353.000000  353.000000  353.000000  353.000000  353.000000
# mean    89.165397   84.617833   84.562380   82.571558   84.406756   85.640042
# std      5.045564    6.506990    7.411646    7.168186    6.285390    5.662337
# min     58.440000   58.740000   51.025000   45.745000   50.120000   62.095000
# 25%     86.780000   80.970000   80.940000   79.050000   81.700000   83.245000
# 50%     89.520000   84.385000   84.990000   82.665000   84.585000   85.450000
# 75%     92.080000   88.370000   88.590000   86.525000   87.535000   88.730000
# max    100.000000  100.000000  100.000000  100.000000   98.440000  100.000000
#
#               Q07         Q08         Q09         Q10  ...         Q18  \
# count  353.000000  353.000000  353.000000  353.000000  ...  353.000000
# mean    83.712153   75.227450   76.325581   73.381246  ...   77.105567
# ...

# %%
unis_2122.describe()
# Out:
#               Q01         Q02         Q03         Q04         Q05         Q06  \
# count  353.000000  353.000000  353.000000  353.000000  353.000000  353.000000
# mean    86.240142   82.085354   82.277819   79.630057   81.600354   83.517663
# std      5.675182    7.205601    7.002414    7.727769    6.757813    5.987453
# min     59.520000   47.725000   56.565000   56.205000   54.145000   56.440000
# 25%     82.835000   77.665000   78.195000   74.410000   77.810000   79.745000
# 50%     86.080000   82.025000   82.465000   78.910000   80.855000   82.895000
# 75%     89.545000   86.490000   86.295000   84.360000   85.165000   87.205000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#               Q07         Q08         Q09         Q10  ...         Q18  \
# count  353.000000  353.000000  353.000000  353.000000  ...  353.000000
# mean    80.540014   73.558839   74.492946   70.805963  ...   71.511303
# ...

# %%
diffu = unis_2122.iloc[:,1:] - unis_1819.iloc[:,1:] #difference from 1819 -> 2122
diffu
# Out:
#         Q01    Q02     Q03     Q04     Q05     Q06    Q07     Q08     Q09  \
# 0    -1.635 -0.355  -0.545  -0.030  -2.150   1.190  0.455  -4.100  -3.310
# 1    -1.010 -1.650   0.235  -3.605  -0.460  -3.995  0.110  -2.875  -3.865
# 2    -3.990 -4.035  -2.610  -6.370  -5.085  -4.625 -5.760  -5.165  -3.575
# 3   -10.175 -8.655 -15.420 -15.845  -4.890  -2.190  1.300 -12.110  -4.830
# 4    -7.775 -1.360   5.540   6.160  -5.560  -0.560 -6.245   6.235  -2.525
# ..      ...    ...     ...     ...     ...     ...    ...     ...     ...
# 348  -4.520 -4.160  -1.905  -4.820  -3.805  -1.500 -5.425  -6.850  -6.655
# 349  -3.805  6.120   5.350   9.300  14.435  10.235  5.650  -4.655  -7.535
# 350  -4.830 -4.225  -0.840  -1.985  -4.425  -2.690 -5.720  -2.905   0.835
# 351  -5.840 -4.390  -0.100  -0.985 -10.675  -0.525  0.685  -5.540   1.850
# 352  -3.355 -5.020  -1.590  -9.715  -4.450  -5.310 -1.780 -11.015 -12.465
#
#         Q10  ...     Q18     Q19     Q20     Q21     Q22     Q23     Q24  \
# ...

# %%
#do this to get red and green
x = np.arange(353)
y = diffu.iloc[:,-1]
mask1 = y < 0
mask2 = y >= 0

plt.bar(x[mask1], y[mask1], color = 'red')
plt.bar(x[mask2], y[mask2], color = 'green')
plt.xlabel("Questions")
#plt.xticks(x, unis_1819.iloc[:,0], rotation = 45)
plt.ylabel("Change in SS % from benchmark")

#plt.ylim([-23,23])
plt.show()

# %%
unis_1819.iloc[6,-1]
# Out:
# 87.5

# %%
print(f" The uni with the largest increase ({max(diffu.iloc[:,-1]):.2f}%): {unis_2122.iloc[diffu.Q27.argmax(),0]}")
print(f" The uni with the largest decrease ({min(diffu.iloc[:,-1]):.2f}%): {unis_2122.iloc[diffu.Q27.argmin(),0]}")
# Out:
#  The uni with the largest increase (27.32%): The SMB Group
#  The uni with the largest decrease (-37.23%): AECC University College

# %% [markdown]
# ### By course

# %%
course_2122.head()
# Out:
#                                   course       Q01       Q02       Q03  \
# 0  Agriculture, food and related studies  0.848417  0.796876  0.780800
# 1    Architecture, building and planning  0.813885  0.784609  0.800091
# 2          Biological and sport sciences  0.882982  0.821448  0.828843
# 3                Business and management  0.859937  0.781681  0.794805
# 4           Combined and general studies  0.854085  0.801465  0.838083
#
#         Q04       Q05       Q06       Q07       Q08       Q09  ...       Q18  \
# 0  0.727643  0.760136  0.814108  0.712944  0.708093  0.714422  ...  0.692980
# 1  0.787250  0.799424  0.823585  0.770105  0.666583  0.680618  ...  0.687076
# 2  0.774331  0.804320  0.829850  0.758726  0.734825  0.730646  ...  0.745247
# 3  0.789777  0.813643  0.852627  0.789272  0.754530  0.742113  ...  0.771117
# 4  0.746840  0.813698  0.867948  0.713996  0.676573  0.673590  ...  0.671960
#
#         Q19       Q20       Q21       Q22       Q23       Q24       Q25  \
# ...

# %%
course_2122.describe()
# Out:
#              Q01        Q02        Q03        Q04        Q05        Q06  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    0.854973   0.800124   0.830421   0.771292   0.800699   0.823045
# std     0.028908   0.047919   0.042399   0.028985   0.037259   0.037813
# min     0.800518   0.700844   0.740562   0.712307   0.749784   0.745896
# 25%     0.843734   0.783221   0.800091   0.759840   0.773058   0.805108
# 50%     0.854085   0.801465   0.830050   0.770537   0.799424   0.824066
# 75%     0.867671   0.835647   0.852252   0.792908   0.813698   0.852627
# max     0.913437   0.895458   0.916595   0.816609   0.879655   0.877170
#
#              Q07        Q08        Q09        Q10  ...        Q18        Q19  \
# count  21.000000  21.000000  21.000000  21.000000  ...  21.000000  21.000000
# mean    0.775000   0.705644   0.716143   0.661829  ...   0.729913   0.774513
# std     0.055073   0.038422   0.036982   0.053039  ...   0.032672   0.028146
# ...

# %%
diffcou = course_2122.iloc[:,1:] - course_1819.iloc[:,1:] #the change from covid per everything
diffcou
# Out:
#          Q01       Q02       Q03       Q04       Q05       Q06       Q07  \
# 0  -0.052201 -0.046945 -0.043474 -0.064733 -0.057983 -0.031244 -0.067244
# 1  -0.050672 -0.034422 -0.044531 -0.026199 -0.020833 -0.037830 -0.039842
# 2  -0.022499 -0.016592 -0.022025 -0.046364 -0.037321 -0.028932 -0.059980
# 3  -0.021857 -0.026268 -0.012227 -0.017787 -0.014206 -0.012214 -0.016937
# 4  -0.066084 -0.042896 -0.056245 -0.048359 -0.043361 -0.001434 -0.032134
# 5  -0.047349 -0.048506 -0.034119 -0.041279 -0.032918 -0.032325 -0.028890
# 6  -0.023382 -0.020460 -0.031787 -0.034025 -0.033912 -0.023002 -0.043095
# 7  -0.027587 -0.035079 -0.032071 -0.048055 -0.031447 -0.026413 -0.037031
# 8  -0.003097 -0.012610 -0.001720 -0.012752  0.003666  0.000537 -0.000809
# 9  -0.020393 -0.024127 -0.024551 -0.033400 -0.032073 -0.015245 -0.056023
# 10 -0.025121 -0.013681 -0.014782 -0.036031 -0.016219 -0.011561 -0.027952
# 11 -0.031531 -0.024921 -0.026128 -0.044020 -0.030615 -0.016687 -0.014718
# ...

# %%
plt.barh(np.arange(21), diffcou["Q27"], color = "r", align = "center")
plt.yticks(np.arange(21), course_1819.iloc[:,0])
plt.ylabel("Change in SS % from benchmark")
plt.show()

# %%
diffcou['Q27'].sort_values()
# Out:
# 4    -0.138167
# 12   -0.100597
# 13   -0.100367
# 18   -0.089294
# 16   -0.081921
# 0    -0.073685
# 20   -0.068270
# 9    -0.063647
# 5    -0.062815
# 15   -0.059044
# 11   -0.056776
# 10   -0.056660
# 1    -0.053514
# 6    -0.052050
# 14   -0.050129
# 2    -0.044137
# 7    -0.042967
# 17   -0.040345
# 3    -0.028987
# 19   -0.011138
# 8    -0.010048
# Name: Q27, dtype: float64

# %%
print(f"Most affected course: {course_1819.iloc[diffcou['Q27'].sort_values().index[0],0]} ")
print(f"Least affected course: {course_1819.iloc[diffcou['Q27'].sort_values().index[-1],0]}")
# Out:
# Most affected course: Combined and general studies
# Least affected course: Engineering and technology
